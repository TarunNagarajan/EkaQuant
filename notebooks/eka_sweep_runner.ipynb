# %% [markdown]
# # EkaQuant: Comprehensive 8-bit & 4-bit Sweep
# This notebook runs the automated `eka_master_sweep.py` script to collect baselines for Qwen 3B, 7B, and Gemma 9B.

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login
user_secrets = UserSecretsClient()
try:
    hf_token = user_secrets.get_secret("HF_TOKEN")
    if hf_token: login(token=hf_token)
except: print("No HF_TOKEN found.")

# !git clone https://github.com/TarunNagarajan/EkaQuant.git
# %cd EkaQuant
# !python eka_master_sweep.py
